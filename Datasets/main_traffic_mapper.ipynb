# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import MinMaxScaler

SEED = 68
rng = np.random.default_rng(SEED)

# --- load the 90-column real traffic data ---
raw_df = pd.read_csv("Base/cell_type_labelled_data_PRB.csv")

# group columns by type (strip trailing digits, e.g. 'Rush1' -> 'Rush')
type_pools = {}
for col in raw_df.columns:
    ctype = re.match(r'[A-Za-z]+', col).group()
    type_pools.setdefault(ctype, []).append(col)

# shuffle each pool once so we can just pop from the end (fast, no replacement)
for ctype in type_pools:
    rng.shuffle(type_pools[ctype])

# --- domain_map: real cell -> type ---
domain_map = {
    'C1': 'Rush', 'C2': 'Hospital', 'C3': 'Rush', 'C4': 'Transport', 'C5': 'Rush',
    'C6': 'Rush', 'C7': 'Rush', 'C9': 'Rush', 'C10': 'Rush', 'C11': 'House',
    'C12': 'Shop', 'C14': 'Rush', 'C15': 'Shop', 'C16': 'Rush', 'C17': 'House',
    'C18': 'Rush', 'C20': 'House', 'C21': 'House', 'C22': 'House', 'C23': 'House',
    'C24': 'House', 'C25': 'House', 'C26': 'Transport', 'C27': 'Shop', 'C28': 'House',
    'C29': 'Rush', 'C30': 'House', 'C31': 'Rush', 'C32': 'Rush', 'C34': 'Shop',
    'C35': 'House', 'C37': 'Transport', 'C38': 'Hospital', 'C39': 'Rush', 'C40': 'Rush',
    'C41': 'Rush', 'C42': 'Rush', 'C43': 'Shop', 'C45': 'House',
    'M1': 'Rush', 'M2': 'Rush', 'M3': 'Transport', 'M4': 'House', 'M5': 'House',
    'M6': 'Shop', 'M7': 'Rush',
}

# --- assign, popping one unused column per cell so nothing is reused ---
final_data = {}
assignment_log = []  # useful to keep for your thesis appendix / sanity checks

for cell, ctype in domain_map.items():
    if not type_pools[ctype]:
        raise ValueError(f"Ran out of '{ctype}' profiles before assigning {cell}")
    chosen_col = type_pools[ctype].pop()
    final_data[cell] = raw_df[chosen_col].values
    assignment_log.append({"cell": cell, "type": ctype, "source_column": chosen_col})

final_df = pd.DataFrame(final_data)

# --- min-max scale each cell's column independently to [0,1] ---
scaler = MinMaxScaler()
final_df[final_df.columns] = scaler.fit_transform(final_df[final_df.columns])

# --- export ---
final_df.to_csv("Base/simulator_ready_traffic_PRB.csv", index=False)
pd.DataFrame(assignment_log).to_csv("Base/cell_assignment_log.csv", index=False)

final_df.head()
# Out:
#          C1        C2        C3        C4        C5        C6        C7  \
# 0  0.004956  0.026025  0.002796  0.059622  0.029399  0.047865  0.006897
# 1  0.022426  0.013903  0.023472  0.090702  0.012820  0.034894  0.012482
# 2  0.000000  0.000000  0.029988  0.055306  0.005726  0.033780  0.019061
# 3  0.054694  0.370120  0.048790  0.099922  0.058752  0.050128  0.068991
# 4  0.016449  0.289379  0.029844  0.102186  0.098897  0.033415  0.066029
#
#          C9       C10       C11  ...       C42       C43       C45        M1  \
# 0  0.015106  0.030611  0.000000  ...  0.003665  0.008131  0.000000  0.000000
# 1  0.009875  0.016250  0.000004  ...  0.000000  0.032356  0.026810  0.018328
# 2  0.000000  0.037693  0.005174  ...  0.017891  0.014734  0.029568  0.017379
# 3  0.185788  0.161537  0.151843  ...  0.065980  0.023334  0.089639  0.134899
# 4  0.195864  0.109818  0.202080  ...  0.075496  0.020440  0.161246  0.204734
#
#          M2        M3        M4        M5        M6        M7
# 0  0.022926  0.000000  0.000000  0.000000  0.000667  0.072263
# 1  0.000000  0.025229  0.022572  0.013055  0.000000  0.067312
# 2  0.011584  0.006165  0.028250  0.009553  0.013465  0.002993
# 3  0.069067  0.131445  0.065850  0.131407  0.107116  0.082771
# 4  0.043722  0.093765  0.195044  0.097344  0.164138  0.076145
#
# [5 rows x 46 columns]

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import MinMaxScaler

SEED = 68
rng = np.random.default_rng(SEED)

# --- load the 90-column real traffic data ---
raw_df = pd.read_csv("Base/cell_type_labelled_data_MR.csv")

# group columns by type (strip trailing digits, e.g. 'Rush1' -> 'Rush')
type_pools = {}
for col in raw_df.columns:
    ctype = re.match(r'[A-Za-z]+', col).group()
    type_pools.setdefault(ctype, []).append(col)

# shuffle each pool once so we can just pop from the end (fast, no replacement)
for ctype in type_pools:
    rng.shuffle(type_pools[ctype])

# --- domain_map: real cell -> type ---
domain_map = {
    'C1': 'Rush', 'C2': 'Hospital', 'C3': 'Rush', 'C4': 'Transport', 'C5': 'Rush',
    'C6': 'Rush', 'C7': 'Rush', 'C9': 'Rush', 'C10': 'Rush', 'C11': 'House',
    'C12': 'Shop', 'C14': 'Rush', 'C15': 'Shop', 'C16': 'Rush', 'C17': 'House',
    'C18': 'Rush', 'C20': 'House', 'C21': 'House', 'C22': 'House', 'C23': 'House',
    'C24': 'House', 'C25': 'House', 'C26': 'Transport', 'C27': 'Shop', 'C28': 'House',
    'C29': 'Rush', 'C30': 'House', 'C31': 'Rush', 'C32': 'Rush', 'C34': 'Shop',
    'C35': 'House', 'C37': 'Transport', 'C38': 'Hospital', 'C39': 'Rush', 'C40': 'Rush',
    'C41': 'Rush', 'C42': 'Rush', 'C43': 'Shop', 'C45': 'House',
    'M1': 'Rush', 'M2': 'Rush', 'M3': 'Transport', 'M4': 'House', 'M5': 'House',
    'M6': 'Shop', 'M7': 'Rush',
}

# --- assign, popping one unused column per cell so nothing is reused ---
final_data = {}
assignment_log = []  # useful to keep for your thesis appendix / sanity checks

for cell, ctype in domain_map.items():
    if not type_pools[ctype]:
        raise ValueError(f"Ran out of '{ctype}' profiles before assigning {cell}")
    chosen_col = type_pools[ctype].pop()
    final_data[cell] = raw_df[chosen_col].values
    assignment_log.append({"cell": cell, "type": ctype, "source_column": chosen_col})

final_df = pd.DataFrame(final_data)

# --- min-max scale each cell's column independently to [0,1] ---
scaler = MinMaxScaler()
final_df[final_df.columns] = scaler.fit_transform(final_df[final_df.columns])

# --- export ---
final_df.to_csv("Base/simulator_ready_traffic_MR.csv", index=False)
pd.DataFrame(assignment_log).to_csv("Base/cell_assignment_log.csv", index=False)

final_df.head()
# Out:
#          C1        C2        C3        C4        C5        C6        C7  \
# 0  0.004640  0.042199  0.034389  0.038981  0.026953  0.013081  0.014508
# 1  0.017192  0.094335  0.039225  0.044870  0.013593  0.004002  0.000000
# 2  0.011637  0.087779  0.013156  0.000000  0.034911  0.000000  0.001806
# 3  0.079595  0.391810  0.040662  0.083665  0.099832  0.070942  0.096318
# 4  0.085629  0.351275  0.041307  0.134874  0.135642  0.044279  0.100295
#
#          C9       C10       C11  ...       C42       C43       C45        M1  \
# 0  0.008866  0.013047  0.024392  ...  0.037955  0.009276  0.000000  0.067982
# 1  0.004780  0.031608  0.000000  ...  0.039307  0.008741  0.019580  0.000000
# 2  0.015901  0.016755  0.013878  ...  0.000000  0.009347  0.006700  0.006305
# 3  0.222096  0.398747  0.275105  ...  0.111635  0.023108  0.223599  0.082724
# 4  0.172808  0.261872  0.234898  ...  0.150238  0.017574  0.288983  0.082690
#
#          M2        M3        M4        M5        M6        M7
# 0  0.018110  0.018736  0.069155  0.000088  0.002803  0.079531
# 1  0.007475  0.000000  0.041079  0.004767  0.069689  0.042792
# 2  0.010800  0.030271  0.008713  0.000845  0.019062  0.080196
# 3  0.071241  0.222430  0.074516  0.159415  0.158446  0.148221
# 4  0.074028  0.204350  0.116905  0.142015  0.126528  0.033813
#
# [5 rows x 46 columns]
