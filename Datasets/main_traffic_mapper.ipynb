# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import MinMaxScaler

SEED = 42
rng = np.random.default_rng(SEED)

# --- load the 90-column real traffic data ---
raw_df = pd.read_csv("Base/cell_type_labelled_data_PRB.csv")

# group columns by type (strip trailing digits, e.g. 'Rush1' -> 'Rush')
type_pools = {}
for col in raw_df.columns:
    ctype = re.match(r'[A-Za-z]+', col).group()
    type_pools.setdefault(ctype, []).append(col)

# shuffle each pool once so we can just pop from the end (fast, no replacement)
for ctype in type_pools:
    rng.shuffle(type_pools[ctype])

# --- domain_map: real cell -> type ---
domain_map = {
    'C1': 'Rush', 'C2': 'Hospital', 'C3': 'Rush', 'C4': 'Transport', 'C5': 'Rush',
    'C6': 'Rush', 'C7': 'Rush', 'C9': 'Rush', 'C10': 'Rush', 'C11': 'House',
    'C12': 'Shop', 'C14': 'Rush', 'C15': 'Shop', 'C16': 'Rush', 'C17': 'House',
    'C18': 'Rush', 'C20': 'House', 'C21': 'House', 'C22': 'House', 'C23': 'House',
    'C24': 'House', 'C25': 'House', 'C26': 'Transport', 'C27': 'Shop', 'C28': 'House',
    'C29': 'Rush', 'C30': 'House', 'C31': 'Rush', 'C32': 'Rush', 'C34': 'Shop',
    'C35': 'House', 'C37': 'Transport', 'C38': 'Hospital', 'C39': 'Rush', 'C40': 'Rush',
    'C41': 'Rush', 'C42': 'Rush', 'C43': 'Shop', 'C45': 'House',
    'M1': 'Rush', 'M2': 'Rush', 'M3': 'Transport', 'M4': 'House', 'M5': 'House',
    'M6': 'Shop', 'M7': 'Rush',
}

# --- assign, popping one unused column per cell so nothing is reused ---
final_data = {}
assignment_log = []  # useful to keep for your thesis appendix / sanity checks

for cell, ctype in domain_map.items():
    if not type_pools[ctype]:
        raise ValueError(f"Ran out of '{ctype}' profiles before assigning {cell}")
    chosen_col = type_pools[ctype].pop()
    final_data[cell] = raw_df[chosen_col].values
    assignment_log.append({"cell": cell, "type": ctype, "source_column": chosen_col})

final_df = pd.DataFrame(final_data)

# --- min-max scale each cell's column independently to [0,1] ---
scaler = MinMaxScaler()
final_df[final_df.columns] = scaler.fit_transform(final_df[final_df.columns])

# --- export ---
final_df.to_csv("Base/simulator_ready_traffic_PRB.csv", index=False)
pd.DataFrame(assignment_log).to_csv("Base/cell_assignment_log.csv", index=False)

final_df.head()
# Out:
#          C1        C2        C3        C4        C5        C6        C7  \
# 0  0.004956  0.000000  0.000428  0.000000  0.003665  0.026821  0.015106
# 1  0.022426  0.040983  0.000000  0.025229  0.000000  0.019878  0.009875
# 2  0.000000  0.000886  0.007039  0.006165  0.017891  0.000000  0.000000
# 3  0.054694  0.273397  0.034753  0.131445  0.065980  0.117259  0.185788
# 4  0.016449  0.378863  0.008974  0.093765  0.075496  0.117254  0.195864
#
#          C9       C10       C11  ...       C42       C43       C45        M1  \
# 0  0.005092  0.016639  0.000000  ...  0.056891  0.000918  0.000000  0.030611
# 1  0.002824  0.022376  0.006605  ...  0.055499  0.001613  0.009504  0.016250
# 2  0.013840  0.042924  0.011025  ...  0.000000  0.000000  0.027257  0.037693
# 3  0.050677  0.066503  0.062840  ...  0.052046  0.189447  0.295068  0.161537
# 4  0.021200  0.096785  0.031975  ...  0.059725  0.220123  0.212820  0.109818
#
#          M2        M3        M4        M5        M6        M7
# 0  0.002796  0.015980  0.000000  0.000170  0.019216  0.018256
# 1  0.023472  0.000000  0.016125  0.000416  0.014469  0.039008
# 2  0.029988  0.032545  0.003919  0.000847  0.020362  0.040774
# 3  0.048790  0.082569  0.110977  0.283145  0.049193  0.029605
# 4  0.029844  0.088128  0.151894  0.278297  0.089351  0.035287
#
# [5 rows x 46 columns]

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import MinMaxScaler

SEED = 42
rng = np.random.default_rng(SEED)

# --- load the 90-column real traffic data ---
raw_df = pd.read_csv("Base/cell_type_labelled_data_MR.csv")

# group columns by type (strip trailing digits, e.g. 'Rush1' -> 'Rush')
type_pools = {}
for col in raw_df.columns:
    ctype = re.match(r'[A-Za-z]+', col).group()
    type_pools.setdefault(ctype, []).append(col)

# shuffle each pool once so we can just pop from the end (fast, no replacement)
for ctype in type_pools:
    rng.shuffle(type_pools[ctype])

# --- domain_map: real cell -> type ---
domain_map = {
    'C1': 'Rush', 'C2': 'Hospital', 'C3': 'Rush', 'C4': 'Transport', 'C5': 'Rush',
    'C6': 'Rush', 'C7': 'Rush', 'C9': 'Rush', 'C10': 'Rush', 'C11': 'House',
    'C12': 'Shop', 'C14': 'Rush', 'C15': 'Shop', 'C16': 'Rush', 'C17': 'House',
    'C18': 'Rush', 'C20': 'House', 'C21': 'House', 'C22': 'House', 'C23': 'House',
    'C24': 'House', 'C25': 'House', 'C26': 'Transport', 'C27': 'Shop', 'C28': 'House',
    'C29': 'Rush', 'C30': 'House', 'C31': 'Rush', 'C32': 'Rush', 'C34': 'Shop',
    'C35': 'House', 'C37': 'Transport', 'C38': 'Hospital', 'C39': 'Rush', 'C40': 'Rush',
    'C41': 'Rush', 'C42': 'Rush', 'C43': 'Shop', 'C45': 'House',
    'M1': 'Rush', 'M2': 'Rush', 'M3': 'Transport', 'M4': 'House', 'M5': 'House',
    'M6': 'Shop', 'M7': 'Rush',
}

# --- assign, popping one unused column per cell so nothing is reused ---
final_data = {}
assignment_log = []  # useful to keep for your thesis appendix / sanity checks

for cell, ctype in domain_map.items():
    if not type_pools[ctype]:
        raise ValueError(f"Ran out of '{ctype}' profiles before assigning {cell}")
    chosen_col = type_pools[ctype].pop()
    final_data[cell] = raw_df[chosen_col].values
    assignment_log.append({"cell": cell, "type": ctype, "source_column": chosen_col})

final_df = pd.DataFrame(final_data)

# --- min-max scale each cell's column independently to [0,1] ---
scaler = MinMaxScaler()
final_df[final_df.columns] = scaler.fit_transform(final_df[final_df.columns])

# --- export ---
final_df.to_csv("Base/simulator_ready_traffic_MR.csv", index=False)
pd.DataFrame(assignment_log).to_csv("Base/cell_assignment_log.csv", index=False)

final_df.head()
# Out:
#          C1        C2        C3        C4        C5        C6        C7  \
# 0  0.004640  0.009008  0.000742  0.018736  0.037955  0.012305  0.008866
# 1  0.017192  0.024064  0.017586  0.000000  0.039307  0.000000  0.004780
# 2  0.011637  0.000541  0.008359  0.030271  0.000000  0.006956  0.015901
# 3  0.079595  0.326185  0.026962  0.222430  0.111635  0.132879  0.222096
# 4  0.085629  0.353262  0.033482  0.204350  0.150238  0.122738  0.172808
#
#          C9       C10       C11  ...       C42       C43       C45        M1  \
# 0  0.000000  0.000000  0.039228  ...  0.050677  0.000000  0.008134  0.013047
# 1  0.000437  0.017085  0.000000  ...  0.038327  0.003338  0.019023  0.031608
# 2  0.001293  0.053636  0.017441  ...  0.012303  0.001794  0.013288  0.016755
# 3  0.035388  0.081397  0.137417  ...  0.057464  0.195614  0.313794  0.398747
# 4  0.054561  0.147651  0.154596  ...  0.019068  0.190564  0.315464  0.261872
#
#          M2        M3        M4        M5        M6        M7
# 0  0.034389  0.022895  0.000000  0.017882  0.016178  0.000000
# 1  0.039225  0.000000  0.001004  0.010418  0.033001  0.027771
# 2  0.013156  0.060552  0.010853  0.024227  0.000000  0.023932
# 3  0.040662  0.107553  0.138620  0.443087  0.136261  0.042138
# 4  0.041307  0.152064  0.155113  0.444738  0.199812  0.025667
#
# [5 rows x 46 columns]
